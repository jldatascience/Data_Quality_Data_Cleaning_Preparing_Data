# %% [markdown]
# # Traitement des valeurs manquantes

# %% [markdown]
# Points traités dans ce notebook :
#
# - une 1ère aperçu des données
# - Voir combien de points de données manquants nous avons
# - Déterminer la raison pour laquelle les données sont manquantes
# - Supprimer les valeurs manquantes
# - Compléter les valeurs manquantes

# %% [markdown]
# # 1ère aperçu des données

# %% [markdown]
# j'exploite un ensemble de données sur les événements survenus lors des matchs de football américain à des fins de démonstration, et un autre df sur les permis de construire délivrés à San Francisco.

# %%
# modules que nous utiliserons
import pandas as pd
import numpy as np

# lire toutes nos données
nfl_data = pd.read_csv("/Users/jl/Downloads/NFL Play by Play 2009-2017 (v4).csv")
sf_permits = pd.read_csv("/Users/jl/Downloads/Building_Permits.csv")

# reproductibilité
np.random.seed(0)
# Out:
# /var/folders/r5/sycktgpj0ln8vbwphhbh5mb00000gn/T/ipykernel_14860/788546147.py:6: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   nfl_data = pd.read_csv("/Users/jl/Downloads/NFL Play by Play 2009-2017 (v4).csv")
# /var/folders/r5/sycktgpj0ln8vbwphhbh5mb00000gn/T/ipykernel_14860/788546147.py:7: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   sf_permits = pd.read_csv("/Users/jl/Downloads/Building_Permits.csv")

# %% [markdown]
# La première chose que je fais lorsque je reçois un nouvel ensemble de données est d'en examiner une partie.
# Cela me permet de vérifier que tout a été lu correctement et d'avoir une idée de ce qui se passe avec les données.
# Dans ce cas, je cherche à voir s'il y a des valeurs manquantes, qui seront représentées par NaN ou None.

# %%
# Je regarde quelques lignes du fichier nfl_data. Je vois déjà une poignée de données manquantes
nfl_data.sample(5)
# Out:
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 244485  2014-10-26  2014102607     18    3   1.0  00:39          1     939.0
# 115340  2011-11-20  2011112000     22    4   1.0  06:47          7     407.0
# 68357   2010-11-14  2010111401      8    2   NaN  00:23          1    1823.0
# 368377  2017-09-24  2017092405     24    4   1.0  08:48          9     528.0
# 384684  2017-11-05  2017110505     11    2   1.0  09:15         10    2355.0
#
#         PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 244485          12.0          TB  ...  1.240299     0.225647     0.774353
# 115340          44.0         OAK  ...       NaN     0.056036     0.943964
# 68357            0.0         CLE  ...       NaN     0.365307     0.634693
# 368377           8.0         CLE  ...  1.075660     0.935995     0.064005
# 384684           0.0         DEN  ...       NaN     0.928474     0.071526
#
#         Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  \
# 244485      0.245582      0.754418  0.225647  0.019935 -0.018156  0.038091
# 115340      0.042963      0.957037  0.943964  0.013073       NaN       NaN
# 68357       0.384697      0.615303  0.634693 -0.019390       NaN       NaN
# 368377      0.921231      0.078769  0.064005  0.014764  0.003866  0.010899
# 384684      0.934641      0.065359  0.071526 -0.006166       NaN       NaN
#
#         Season
# 244485    2014
# 115340    2011
# 68357     2010
# 368377    2017
# 384684    2017
#
# [5 rows x 102 columns]

# %% [markdown]
# il y a bien des valeurs manquantes. Qu'en est-il de l'ensemble de données sf_permits ?

# %%
# Je regarde quelques lignes du fichier nfl_data. Je vois déjà une poignée de données manquantes
sf_permits.sample(5)
# idem
# Out:
#       Permit Number  Permit Type  Permit Type Definition Permit Creation Date  \
# 49009  201405226535            8  otc alterations permit           05/22/2014
# 46655  201405014687            8  otc alterations permit           05/01/2014
# 74211  201501297005            8  otc alterations permit           01/29/2015
# 55407  201407221800            8  otc alterations permit           07/22/2014
# 17030  201306270613            8  otc alterations permit           06/27/2013
#
#       Block   Lot  Street Number Street Number Suffix  Street Name  \
# 49009  0997  017A            200                  NaN       Walnut
# 46655  1219   029           1263                  NaN          Oak
# 74211  0334   004            325                  NaN  Leavenworth
# 55407  0857   001            218                  NaN     Buchanan
# 17030  5891   015            119                  NaN      Maynard
#
#       Street Suffix  ...  Existing Construction Type  \
# 49009            St  ...                         5.0
# 46655            St  ...                         5.0
# 74211            St  ...                         3.0
# 55407            St  ...                         NaN
# 17030            St  ...                         5.0
#
#       Existing Construction Type Description Proposed Construction Type  \
# 49009                         wood frame (5)                        5.0
# 46655                         wood frame (5)                        5.0
# 74211                          constr type 3                        3.0
# 55407                                    NaN                        NaN
# 17030                         wood frame (5)                        5.0
#
#       Proposed Construction Type Description Site Permit Supervisor District  \
# 49009                         wood frame (5)         NaN                 2.0
# 46655                         wood frame (5)         NaN                 NaN
# 74211                          constr type 3         NaN                 6.0
# 55407                                    NaN         NaN                 8.0
# 17030                         wood frame (5)         NaN                11.0
#
#       Neighborhoods - Analysis Boundaries  Zipcode  \
# 49009                    Presidio Heights  94118.0
# 46655                                 NaN      NaN
# 74211                          Tenderloin  94109.0
# 55407                        Hayes Valley  94102.0
# 17030                           Excelsior  94112.0
#
#                                        Location      Record ID
# 49009  (37.78958158007647, -122.44873860281018)   134291486469
# 46655                                       NaN  1340469240465
# 74211  (37.78405819312474, -122.41456846296983)   136938469855
# 55407  (37.77234985626402, -122.42627871236607)  1349630492927
# 17030  (37.72952811045384, -122.42781140712628)  1309434190479
#
# [5 rows x 43 columns]

# %% [markdown]
# # Voir combien de points de données manquants nous avons

# %% [markdown]
# nous avons quelques valeurs manquantes. Voyons combien nous en avons dans chaque colonne.

# %%
# déterminer le nombre de points de données manquants par colonne
missing_values_count = nfl_data.isnull().sum()

# %%
# visualiser le nombre de points manquants dans les dix premières colonnes
missing_values_count[0:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            61154
# time              224
# TimeUnder           0
# TimeSecs          224
# PlayTimeDiff      444
# SideofField       528
# dtype: int64

# %% [markdown]
# Cela semble beaucoup ! Il serait peut-être utile de connaître le pourcentage de valeurs manquantes dans notre ensemble de données pour nous donner une meilleure idée de l'ampleur du problème :

# %%
# Combien de valeurs manquantes avons-nous au total ?
total_cells = np.product(nfl_data.shape)
total_missing = missing_values_count.sum()

# Pourcentage de données manquantes
(total_missing/total_cells) * 100
# Out:
# 24.87214126835169

# %% [markdown]
# Près d'un quart des cellules de cet ensemble de données sont vides !
#
# Dans l'étape suivante, nous allons examiner de plus près certaines des colonnes présentant des valeurs manquantes et essayer de comprendre ce qui se passe.

# %%
# quel pourcentage de l'ensemble de données sf_permits est manquant

# déterminer le nombre de points de données manquants par colonne
missing_values_count_sf_permits = sf_permits.isnull().sum()

# visualiser le nombre de points manquants dans les dix premières colonnes
missing_values_count_sf_permits[0:10]
# Out:
# Permit Number                  0
# Permit Type                    0
# Permit Type Definition         0
# Permit Creation Date           0
# Block                          0
# Lot                            0
# Street Number                  0
# Street Number Suffix      196684
# Street Name                    0
# Street Suffix               2768
# dtype: int64

# %%
# Combien de valeurs manquantes avons-nous au total ?
total_cells_sf_permits = np.product(sf_permits.shape)

total_missing_sf_permits = missing_values_count_sf_permits.sum()

# Pourcentage de données manquantes
(total_missing_sf_permits/total_cells_sf_permits) * 100
# Out:
# 26.26002315058403

# %% [markdown]
# # Déterminer pourquoi les données sont manquantes
#
# Pour traiter les valeurs manquantes, il faut faire preuve d'intuition pour comprendre pourquoi la valeur est manquante.
#
# Question à se poser pour résoudre ce problème :
#
# Cette valeur est-elle manquante parce qu'elle n'a pas été enregistrée ou parce qu'elle n'existe pas ?
#
# Si une valeur est manquante parce qu'elle n'existe pas (comme la taille de l'enfant le plus âgé d'une personne qui n'a pas d'enfant), il est inutile d'essayer de deviner ce qu'elle pourrait être. Il est probable que je souhaite conserver ces valeurs sous forme de NaN, dans ce cas.
#
# En revanche, si une valeur est manquante parce qu'elle n'a pas été enregistrée, je vais essayer de deviner ce qu'elle aurait pu être en me basant sur les autres valeurs de cette colonne et de cette ligne. C'est ce qu'on appelle l' "imputation". Je vais aborder cette notion par la suite.

# %%
# Prenons un exemple. En regardant le nombre de valeurs manquantes dans le df nfl_data, je remarque que la colonne TimesSec contient beaucoup de valeurs manquantes :

# regarder le nombre de points manquants dans les dix premières colonnes
missing_values_count[0:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            61154
# time              224
# TimeUnder           0
# TimeSecs          224
# PlayTimeDiff      444
# SideofField       528
# dtype: int64

# %% [markdown]
# En consultant la documentation, je constate que cette colonne contient des informations sur le nombre de secondes restantes dans le jeu lorsque le jeu a été effectué. Cela signifie que ces valeurs sont probablement manquantes parce qu'elles n'ont pas été enregistrées, plutôt que parce qu'elles n'existent pas. Il serait donc logique que j'essaie de deviner ce qu'elles devraient être plutôt que de les laisser comme NA.
#
# D'autre part, d'autres champs, comme PenalizedTeam, comportent également de nombreux champs manquants. Dans ce cas, cependant, le champ est manquant parce que s'il n'y a pas eu de pénalité, cela n'a pas de sens de dire quelle équipe a été pénalisée. Pour cette colonne, il serait plus logique de la laisser vide ou d'ajouter une troisième valeur comme "neither" et de l'utiliser pour remplacer les NA.
#
# Bonne pratique : si l'on travaille avec un jeu de données que nous avons obtenu d'une autre personne, on peut également essayer de la contacter pour obtenir plus d'informations.
#
# Si j'effectue une analyse très minutieuse des données, c'est à ce moment-là que j'examinerai chaque colonne individuellement afin de déterminer la meilleure stratégie pour combler les valeurs manquantes.
# Dans la suite de ce notebook, j'aborderai quelques techniques "rapides et sales" qui m'aideront à combler les valeurs manquantes, mais qui finiront probablement par supprimer des informations utiles ou par ajouter du bruit à mes données.

# %%
# Examinons les colonnes Street Number Suffix et Zipcode de l'ensemble de données sf_permits
sf_permits.sample(60)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 41194   201403070180            8            otc alterations permit
# 144680  201612094578            6                       demolitions
# 27305   201310088810            3  additions alterations or repairs
# 123178  201605056661            3  additions alterations or repairs
# 85836        M587687            8            otc alterations permit
# 89363   201506189294            8            otc alterations permit
# 9777         M385908            8            otc alterations permit
# 115559  201602240395            8            otc alterations permit
# 14974   201306078935            8            otc alterations permit
# 21460   201308134178            8            otc alterations permit
# 69455        M541470            8            otc alterations permit
# 21132        M415607            8            otc alterations permit
# 167692  201708043891            8            otc alterations permit
# 13873        M397687            8            otc alterations permit
# 83514        M580687            8            otc alterations permit
# 78885   201503130837            8            otc alterations permit
# 146338  201612296222            8            otc alterations permit
# 80955   201504012545            8            otc alterations permit
# 184510  201709290031            8            otc alterations permit
# 21166        M415687            8            otc alterations permit
# 17432   201307020945            8            otc alterations permit
# 194852  201801188954            8            otc alterations permit
# 13967   201305298090            8            otc alterations permit
# 187263  201710262385            8            otc alterations permit
# 122522  201604296114            8            otc alterations permit
# 162178  201707071248            8            otc alterations permit
# 188205  201711063200            8            otc alterations permit
# 29398        M439327            8            otc alterations permit
# 114438  201602169669            8            otc alterations permit
# 107792  201512034092            8            otc alterations permit
# 52342   201406249274            3  additions alterations or repairs
# 68376   201411202170            8            otc alterations permit
# 77556   201503029732            8            otc alterations permit
# 118889  201603253140            8            otc alterations permit
# 31014   201311131825            8            otc alterations permit
# 176123  201704275082            8            otc alterations permit
# 88656   201506118725            8            otc alterations permit
# 141939       M737167            8            otc alterations permit
# 45168   201404173437            3  additions alterations or repairs
# 164498  201612013904            8            otc alterations permit
# 83405   201504234452            8            otc alterations permit
# 124020       M690447            8            otc alterations permit
# 102663  201510190045            8            otc alterations permit
# 144424  201612074326            8            otc alterations permit
# 167688  201708043889            8            otc alterations permit
# 195907  201801299820            8            otc alterations permit
# 47926   201405145693            8            otc alterations permit
# 176245  201705035615            8            otc alterations permit
# 8485    201304023568            8            otc alterations permit
# 5023         M372768            8            otc alterations permit
# 96355   201508214976            8            otc alterations permit
# 96430        M617207            8            otc alterations permit
# 156685       M756847            8            otc alterations permit
# 5342    201302260987            8            otc alterations permit
# 31630   201311202328            8            otc alterations permit
# 114313  201602129555            8            otc alterations permit
# 195906  201801299821            8            otc alterations permit
# 126590  201606089365            8            otc alterations permit
# 184965  201710040432            8            otc alterations permit
# 184094  201709279663            8            otc alterations permit
#
#        Permit Creation Date  Block   Lot  Street Number Street Number Suffix  \
# 41194            03/07/2014   0322   001            601                  NaN
# 144680           12/09/2016   0859   022            228                  NaN
# 27305            10/08/2013   3564  070A            355                  NaN
# 123178           05/05/2016   1459   011            478                  NaN
# 85836            05/15/2015   2752   026            321                  NaN
# 89363            06/18/2015   0306   006            432                  NaN
# 9777             04/16/2013   1742   034           1220                  NaN
# 115559           02/24/2016   3569   014           2072                  NaN
# 14974            06/07/2013   1647   036            700                  NaN
# 21460            08/13/2013   1135   025            821                  NaN
# 69455            12/05/2014   5743   021            655                  NaN
# 21132            08/09/2013   1053   001           1679                  NaN
# 167692           08/04/2017   0239   013            456                  NaN
# 13873            05/29/2013   3756   045           1221                  NaN
# 83514            04/24/2015   0225   004            725                  NaN
# 78885            03/13/2015   3063   033            179                  NaN
# 146338           12/29/2016   3731   133           1097                  NaN
# 80955            04/01/2015   0228   039            475                  NaN
# 184510           09/29/2017   6522   023           3140                  NaN
# 21166            08/09/2013   3587   028           3694                  NaN
# 17432            07/02/2013   3545   028            185                  NaN
# 194852           01/18/2018   0309   010            166                  NaN
# 13967            05/29/2013  7045B   019            264                  NaN
# 187263           10/26/2017   1040   042            330                  NaN
# 122522           04/29/2016   2845   013             20                  NaN
# 162178           07/07/2017   2660   003            328                  NaN
# 188205           11/06/2017   2840   002             80                  NaN
# 29398            10/29/2013   1341   018           1650                  NaN
# 114438           02/16/2016  1928B   037           1717                  NaN
# 107792           12/03/2015   2625   002              4                  NaN
# 52342            06/24/2014   0847   020            688                  NaN
# 68376            11/20/2014   5653   006            126                  NaN
# 77556            03/02/2015   0827   003            537                  NaN
# 118889           03/25/2016   0645   013           1424                  NaN
# 31014            11/13/2013   5617   022            205                  NaN
# 176123           04/27/2017   3086   038            659                  NaN
# 88656            06/11/2015   0264   004              1                  NaN
# 141939           11/07/2016   6473   006             86                  NaN
# 45168            04/17/2014   1173   002             10                  NaN
# 164498           12/01/2016   3642   019           3266                  NaN
# 83405            04/23/2015   5475   011           1081                  NaN
# 124020           05/12/2016   0636  018A           2100                  NaN
# 102663           10/19/2015   3656   006           1082                  NaN
# 144424           12/07/2016   1255   011           1359                  NaN
# 167688           08/04/2017   1370   021           4800                  NaN
# 195907           01/29/2018   1279   069            484                  NaN
# 47926            05/14/2014   2623   093            101                  NaN
# 176245           05/03/2017   6797   014             54                  NaN
# 8485             04/02/2013   6604   043           1543                  NaN
# 5023             02/22/2013   2768   024            475                  NaN
# 96355            08/21/2015   2884   021            159                  NaN
# 96430            08/24/2015   0611   002           2327                  NaN
# 156685           01/30/2017   0127   014            947                  NaN
# 5342             02/26/2013   7537   071           1803                  NaN
# 31630            11/20/2013   2835   042             15                  NaN
# 114313           02/12/2016   4162   046            959                  NaN
# 195906           01/29/2018   4914   032           1279                  NaN
# 126590           06/08/2016   0293   009            255                  NaN
# 184965           10/04/2017   3558   152           2191                  NaN
# 184094           09/27/2017   0285   006            450                  NaN
#
#         Street Name Street Suffix  ...  Existing Construction Type  \
# 41194      Ofarrell            St  ...                         3.0
# 144680     Fillmore            St  ...                         5.0
# 27305           Noe            St  ...                         5.0
# 123178         28th            Av  ...                         5.0
# 85836   Collingwood            St  ...                         NaN
# 89363         Geary            St  ...                         3.0
# 9777           09th            Av  ...                         NaN
# 115559      Mission            St  ...                         5.0
# 14974          05th            Av  ...                         5.0
# 21460          Anza            St  ...                         5.0
# 69455       Andover            St  ...                         NaN
# 21132     Broderick            St  ...                         NaN
# 167692   Montgomery            St  ...                         1.0
# 13873        Folsom            St  ...                         NaN
# 83514         Grant            Av  ...                         NaN
# 78885       Melrose            Av  ...                         5.0
# 146338       Howard            St  ...                         5.0
# 80955       Sansome            St  ...                         1.0
# 184510         25th            St  ...                         5.0
# 21166          19th            St  ...                         NaN
# 17432       Dolores            St  ...                         3.0
# 194852        Geary            St  ...                         1.0
# 13967         Foote            Av  ...                         5.0
# 187263     Arguello            Bl  ...                         5.0
# 122522    Crestline            Dr  ...                         5.0
# 162178      Corbett            Av  ...                         5.0
# 188205    Castenada            Av  ...                         5.0
# 29398          Lake            St  ...                         NaN
# 114438         15th            Av  ...                         5.0
# 107792     Douglass            St  ...                         5.0
# 52342        Haight            St  ...                         5.0
# 68376      Prentiss            St  ...                         5.0
# 77556      Fillmore            St  ...                         5.0
# 118889         Polk            St  ...                         3.0
# 31014      Virginia            Av  ...                         5.0
# 176123      Mangels            Av  ...                         5.0
# 88656    California            St  ...                         1.0
# 141939     Whittier            St  ...                         NaN
# 45168        Loyola            Tr  ...                         5.0
# 164498         24th            St  ...                         5.0
# 83405           Key            Av  ...                         5.0
# 124020     Fillmore            St  ...                         NaN
# 102663          Noe            St  ...                         5.0
# 144424      Masonic            Av  ...                         5.0
# 167688   California            St  ...                         5.0
# 195907    Belvedere            St  ...                         NaN
# 47926        States            St  ...                         5.0
# 176245      Francis            St  ...                         5.0
# 8485        Diamond            St  ...                         5.0
# 5023         Eureka            St  ...                         NaN
# 96355      Dorantes            Av  ...                         5.0
# 96430      Fillmore            St  ...                         NaN
# 156685        Green            St  ...                         NaN
# 5342        Diamond            St  ...                         5.0
# 31630     Dellbrook            Av  ...                         5.0
# 114313    Wisconsin            St  ...                         5.0
# 195906       Egbert            Av  ...                         5.0
# 126590       Sutter            St  ...                         1.0
# 184965       Market            St  ...                         1.0
# 184094       Sutter            St  ...                         1.0
#
#        Existing Construction Type Description Proposed Construction Type  \
# 41194                           constr type 3                        3.0
# 144680                         wood frame (5)                        NaN
# 27305                          wood frame (5)                        5.0
# 123178                         wood frame (5)                        5.0
# 85836                                     NaN                        NaN
# 89363                           constr type 3                        3.0
# 9777                                      NaN                        NaN
# 115559                         wood frame (5)                        5.0
# 14974                          wood frame (5)                        5.0
# 21460                          wood frame (5)                        5.0
# 69455                                     NaN                        NaN
# 21132                                     NaN                        NaN
# 167692                          constr type 1                        1.0
# 13873                                     NaN                        NaN
# 83514                                     NaN                        NaN
# 78885                          wood frame (5)                        5.0
# 146338                         wood frame (5)                        5.0
# 80955                           constr type 1                        1.0
# 184510                         wood frame (5)                        5.0
# 21166                                     NaN                        NaN
# 17432                           constr type 3                        3.0
# 194852                          constr type 1                        1.0
# 13967                          wood frame (5)                        5.0
# 187263                         wood frame (5)                        5.0
# 122522                         wood frame (5)                        5.0
# 162178                         wood frame (5)                        5.0
# 188205                         wood frame (5)                        5.0
# 29398                                     NaN                        NaN
# 114438                         wood frame (5)                        5.0
# 107792                         wood frame (5)                        5.0
# 52342                          wood frame (5)                        5.0
# 68376                          wood frame (5)                        5.0
# 77556                          wood frame (5)                        5.0
# 118889                          constr type 3                        3.0
# 31014                          wood frame (5)                        5.0
# 176123                         wood frame (5)                        5.0
# 88656                           constr type 1                        1.0
# 141939                                    NaN                        NaN
# 45168                          wood frame (5)                        5.0
# 164498                         wood frame (5)                        5.0
# 83405                          wood frame (5)                        5.0
# 124020                                    NaN                        NaN
# 102663                         wood frame (5)                        5.0
# 144424                         wood frame (5)                        5.0
# 167688                         wood frame (5)                        5.0
# 195907                                    NaN                        NaN
# 47926                          wood frame (5)                        5.0
# 176245                         wood frame (5)                        5.0
# 8485                           wood frame (5)                        5.0
# 5023                                      NaN                        NaN
# 96355                          wood frame (5)                        5.0
# 96430                                     NaN                        NaN
# 156685                                    NaN                        NaN
# 5342                           wood frame (5)                        5.0
# 31630                          wood frame (5)                        5.0
# 114313                         wood frame (5)                        5.0
# 195906                         wood frame (5)                        5.0
# 126590                          constr type 1                        1.0
# 184965                          constr type 1                        1.0
# 184094                          constr type 1                        1.0
#
#        Proposed Construction Type Description Site Permit Supervisor District  \
# 41194                           constr type 3         NaN                 6.0
# 144680                                    NaN         NaN                 5.0
# 27305                          wood frame (5)           Y                 8.0
# 123178                         wood frame (5)         NaN                 1.0
# 85836                                     NaN         NaN                 8.0
# 89363                           constr type 3         NaN                 3.0
# 9777                                      NaN         NaN                 5.0
# 115559                         wood frame (5)         NaN                 9.0
# 14974                          wood frame (5)         NaN                 1.0
# 21460                          wood frame (5)         NaN                 1.0
# 69455                                     NaN         NaN                 9.0
# 21132                                     NaN         NaN                 2.0
# 167692                          constr type 1         NaN                 3.0
# 13873                                     NaN         NaN                 6.0
# 83514                                     NaN         NaN                 3.0
# 78885                          wood frame (5)         NaN                 7.0
# 146338                         wood frame (5)         NaN                 6.0
# 80955                           constr type 1         NaN                 3.0
# 184510                         wood frame (5)         NaN                 9.0
# 21166                                     NaN         NaN                 8.0
# 17432                           constr type 3         NaN                 8.0
# 194852                          constr type 1         NaN                 3.0
# 13967                          wood frame (5)         NaN                11.0
# 187263                         wood frame (5)         NaN                 2.0
# 122522                         wood frame (5)         NaN                 8.0
# 162178                         wood frame (5)         NaN                 8.0
# 188205                         wood frame (5)         NaN                 7.0
# 29398                                     NaN         NaN                 2.0
# 114438                         wood frame (5)         NaN                 7.0
# 107792                         wood frame (5)         NaN                 8.0
# 52342                          wood frame (5)         NaN                 5.0
# 68376                          wood frame (5)         NaN                 9.0
# 77556                          wood frame (5)         NaN                 5.0
# 118889                          constr type 3         NaN                 3.0
# 31014                          wood frame (5)         NaN                 9.0
# 176123                         wood frame (5)         NaN                 7.0
# 88656                           constr type 1         NaN                 3.0
# 141939                                    NaN         NaN                11.0
# 45168                          wood frame (5)           Y                 1.0
# 164498                         wood frame (5)         NaN                 9.0
# 83405                          wood frame (5)         NaN                10.0
# 124020                                    NaN         NaN                 2.0
# 102663                         wood frame (5)         NaN                 8.0
# 144424                         wood frame (5)         NaN                 5.0
# 167688                         wood frame (5)         NaN                 1.0
# 195907                                    NaN         NaN                 5.0
# 47926                          wood frame (5)         NaN                 8.0
# 176245                         wood frame (5)         NaN                11.0
# 8485                           wood frame (5)         NaN                 8.0
# 5023                                      NaN         NaN                 8.0
# 96355                          wood frame (5)         NaN                 7.0
# 96430                                     NaN         NaN                 2.0
# 156685                                    NaN         NaN                 3.0
# 5342                           wood frame (5)         NaN                 8.0
# 31630                          wood frame (5)         NaN                 7.0
# 114313                         wood frame (5)         NaN                10.0
# 195906                         wood frame (5)         NaN                10.0
# 126590                          constr type 1         NaN                 3.0
# 184965                          constr type 1         NaN                 8.0
# 184094                          constr type 1         NaN                 3.0
#
#        Neighborhoods - Analysis Boundaries  Zipcode  \
# 41194                           Tenderloin  94109.0
# 144680                        Hayes Valley  94117.0
# 27305                  Castro/Upper Market  94114.0
# 123178                      Outer Richmond  94121.0
# 85836                  Castro/Upper Market  94114.0
# 89363                           Tenderloin  94102.0
# 9777                          Inner Sunset  94122.0
# 115559                             Mission  94110.0
# 14974                       Inner Richmond  94118.0
# 21460                    Lone Mountain/USF  94118.0
# 69455                       Bernal Heights  94110.0
# 21132                      Pacific Heights  94115.0
# 167692      Financial District/South Beach  94104.0
# 13873                      South of Market  94103.0
# 83514                            Chinatown  94108.0
# 78885                   West of Twin Peaks  94127.0
# 146338                     South of Market  94103.0
# 80955                            Chinatown  94111.0
# 184510                             Mission  94110.0
# 21166                              Mission  94110.0
# 17432                              Mission  94103.0
# 194852      Financial District/South Beach  94108.0
# 13967                        Outer Mission  94112.0
# 187263                    Presidio Heights  94118.0
# 122522                          Twin Peaks  94131.0
# 162178                 Castro/Upper Market  94114.0
# 188205                  West of Twin Peaks  94116.0
# 29398                             Seacliff  94121.0
# 114438                        Inner Sunset  94122.0
# 107792                 Castro/Upper Market  94114.0
# 52342                       Haight Ashbury  94117.0
# 68376                       Bernal Heights  94110.0
# 77556                         Hayes Valley  94117.0
# 118889                            Nob Hill  94109.0
# 31014                       Bernal Heights  94110.0
# 176123                  West of Twin Peaks  94127.0
# 88656       Financial District/South Beach  94111.0
# 141939                           Excelsior  94112.0
# 45168                    Lone Mountain/USF  94117.0
# 164498                             Mission  94110.0
# 83405                Bayview Hunters Point  94124.0
# 124020                     Pacific Heights  94115.0
# 102663                          Noe Valley  94114.0
# 144424                      Haight Ashbury  94117.0
# 167688                      Inner Richmond  94118.0
# 195907                      Haight Ashbury  94117.0
# 47926                  Castro/Upper Market  94114.0
# 176245                       Outer Mission  94112.0
# 8485                            Noe Valley  94131.0
# 5023                            Noe Valley  94114.0
# 96355                   West of Twin Peaks  94116.0
# 96430                      Pacific Heights  94115.0
# 156685                            Nob Hill  94133.0
# 5342                             Glen Park  94131.0
# 31630                           Twin Peaks  94131.0
# 114313                        Potrero Hill  94107.0
# 195906               Bayview Hunters Point  94124.0
# 126590      Financial District/South Beach  94108.0
# 184965                 Castro/Upper Market  94114.0
# 184094      Financial District/South Beach  94108.0
#
#                                          Location      Record ID
# 41194    (37.78528309870539, -122.41478641316387)   133475969504
# 144680   (37.77163988547394, -122.43008085845331)   144691483298
# 27305     (37.76334686651608, -122.4327133688931)  1320215435912
# 123178  (37.780442718742684, -122.48767416153478)  1422154100611
# 85836    (37.75721787999552, -122.43545075658255)  1381792418685
# 89363    (37.78726475349522, -122.41037579292663)   138553367356
# 9777    (37.765501505876266, -122.46608376737706)  1301844363618
# 115559   (37.76384499486115, -122.41987268743213)  1413789404944
# 14974   (37.775286352650575, -122.46251703251735)  1307285108390
# 21460   (37.779881880252844, -122.45513719478035)  1314049492418
# 69455    (37.73534508943777, -122.41655876388155)  1364355188337
# 21132    (37.78571670042608, -122.44185570015252)   131370988353
# 167692   (37.793566462110775, -122.4026859106026)  1473321297076
# 13873    (37.77447275810478, -122.41029698628046)  1306138166446
# 83514   (37.793728447850015, -122.40646388311615)   137924563218
# 78885   (37.733586105621306, -122.44611316577175)  1374303151276
# 146338  (37.777995101226765, -122.40891444449517)  1449016412366
# 80955    (37.79455504873896, -122.40191811074821)  1376515296673
# 184510  (37.751127732624255, -122.41268024381499)  1481672206132
# 21166    (37.76008931057433, -122.42536047804876)  1313743160309
# 17432     (37.7665678532868, -122.42620153911317)  1309863246984
# 194852  (37.787887811204506, -122.40613381903422)   149401669279
# 13967    (37.71509326180831, -122.44746276003046)  1306235218991
# 187263   (37.78502928618821, -122.45876407838782)   148497187967
# 122522   (37.74994905689047, -122.44569207714115)  1421402246256
# 162178   (37.76009642640273, -122.44526065196318)  1469604141191
# 188205   (37.74982713428291, -122.46229534782313)  1486101145675
# 29398   (37.786297574176565, -122.47748221052123)   132241196355
# 114438    (37.7559623771236, -122.47281854761141)  1412518120844
# 107792   (37.76337610070565, -122.43982327211401)  1405307139975
# 52342    (37.77196196216392, -122.43353751743527)   134641083025
# 68376    (37.74100430550634, -122.41219189409219)  1363226185855
# 77556    (37.77448065785269, -122.43122196947229)  1372887237439
# 118889   (37.79006440167658, -122.42032352405569)   141742977516
# 31014    (37.74239167671147, -122.41914050054422)  1324090185024
# 176123  (37.732818310200706, -122.45251498873108)  1461082151861
# 88656    (37.79312060864542, -122.39698170721115)   138477766082
# 141939   (37.70916408724642, -122.44802709301565)  1443608204200
# 45168    (37.77577405696441, -122.44869137047903)   133892291302
# 164498   (37.75249406266713, -122.41781004248826)  1445982412314
# 83405    (37.71959108083401, -122.39773170756253)  1379129182782
# 124020   (37.78916120211372, -122.43367898605453)   142305977169
# 102663   (37.75167067933195, -122.43221894319412)  1399769164244
# 144424  (37.768169445711194, -122.44518405927082)  1446588361080
# 167688    (37.7848564863469, -122.46903215122717)   147331597154
# 195907   (37.76368600894481, -122.44785051206077)  1495188507004
# 47926   (37.763051158296236, -122.43753013789994)  1341794139889
# 176245   (37.72730165947362, -122.43434561460258)  1461794213415
# 8485      (37.7449709098559, -122.43542995015378)  1300479208954
# 5023      (37.7547368499694, -122.43738669505271)  1296847143689
# 96355   (37.745291539653635, -122.46400172271348)  1393026146496
# 96430   (37.791148399503996, -122.43459786601377)   139310576304
# 156685   (37.79852728723469, -122.41456852382686)   146270159969
# 5342     (37.74298666244527, -122.43524689915756)  1297176228105
# 31630     (37.75073915203772, -122.4538038096975)  1324743145572
# 114313  (37.755411678190704, -122.39844498774698)  1412387171763
# 195906   (37.72121348396637, -122.39059740836929)  1495187176100
# 126590  (37.789425195152596, -122.40475289313132)   142592467123
# 184965  (37.765796331506394, -122.43058780170773)  1482216489766
# 184094   (37.78967479323549, -122.40783987245506)   148117866980
#
# [60 rows x 43 columns]

# %% [markdown]
# En regardant les colonnes Street Number Suffix et Zipcode de l'ensemble de données sf_permits, ces deux colonnes contiennent des valeurs manquantes.
#
# Les valeurs de la colonne Street Number Suffix sont normalement manquantes parce qu'elles n'existent pas
#
# Certaines valeurs de la colonne Zipcode sont manquantes parce qu'elles n'ont pas été enregistrées

# %% [markdown]
# # Supprimer les valeurs manquantes
#
# Si l'on est pris par le temps, on peut supprimer les lignes ou les colonnes qui contiennent des valeurs manquantes.
# Remarque : je ne recommande généralement pas cette approche pour les projets importants ! Il vaut généralement la peine de prendre le temps de parcourir les données et d'examiner attentivement toutes les colonnes contenant des valeurs manquantes, une par une, afin d'apprendre à connaître notre ensemble de données.
#
# Si l'on veut supprimer les lignes avec des valeurs manquantes, pandas dispose d'une fonction pratique, dropna(), pour nous aider à le faire. Je vais la tester sur notre jeu de données NFL

# %%
# supprimer toutes les lignes contenant une valeur manquante
nfl_data.dropna()
# Out:
# Empty DataFrame
# Columns: [Date, GameID, Drive, qtr, down, time, TimeUnder, TimeSecs, PlayTimeDiff, SideofField, yrdln, yrdline100, ydstogo, ydsnet, GoalToGo, FirstDown, posteam, DefensiveTeam, desc, PlayAttempted, Yards.Gained, sp, Touchdown, ExPointResult, TwoPointConv, DefTwoPoint, Safety, Onsidekick, PuntResult, PlayType, Passer, Passer_ID, PassAttempt, PassOutcome, PassLength, AirYards, YardsAfterCatch, QBHit, PassLocation, InterceptionThrown, Interceptor, Rusher, Rusher_ID, RushAttempt, RunLocation, RunGap, Receiver, Receiver_ID, Reception, ReturnResult, Returner, BlockingPlayer, Tackler1, Tackler2, FieldGoalResult, FieldGoalDistance, Fumble, RecFumbTeam, RecFumbPlayer, Sack, Challenge.Replay, ChalReplayResult, Accepted.Penalty, PenalizedTeam, PenaltyType, PenalizedPlayer, Penalty.Yards, PosTeamScore, DefTeamScore, ScoreDiff, AbsScoreDiff, HomeTeam, AwayTeam, Timeout_Indicator, Timeout_Team, posteam_timeouts_pre, HomeTimeouts_Remaining_Pre, AwayTimeouts_Remaining_Pre, HomeTimeouts_Remaining_Post, AwayTimeouts_Remaining_Post, No_Score_Prob, Opp_Field_Goal_Prob, Opp_Safety_Prob, Opp_Touchdown_Prob, Field_Goal_Prob, Safety_Prob, Touchdown_Prob, ExPoint_Prob, TwoPoint_Prob, ExpPts, EPA, airEPA, yacEPA, Home_WP_pre, Away_WP_pre, Home_WP_post, Away_WP_post, Win_Prob, WPA, airWPA, ...]
# Index: []
#
# [0 rows x 102 columns]

# %% [markdown]
# Toutes nos données ont été supprimées !
# En effet, chaque ligne de notre ensemble de données comporte au moins une valeur manquante. Nous pourrions avoir plus de chance en supprimant toutes les colonnes qui ont au moins une valeur manquante à la place.

# %%
# supprimer toutes les colonnes avec au moins une valeur manquante
columns_with_na_dropped = nfl_data.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#          Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0  2009-09-10  2009091000      1    1         15        0       0
# 1  2009-09-10  2009091000      1    1         15       10       5
# 2  2009-09-10  2009091000      1    1         15        5       2
# 3  2009-09-10  2009091000      1    1         14        8       2
# 4  2009-09-10  2009091000      1    1         14        8       2
#
#    PlayAttempted  Yards.Gained  sp  ...  Timeout_Indicator  Timeout_Team  \
# 0              1            39   0  ...                  0          None
# 1              1             5   0  ...                  0          None
# 2              1            -3   0  ...                  0          None
# 3              1             0   0  ...                  0          None
# 4              1             0   0  ...                  0          None
#
#    posteam_timeouts_pre HomeTimeouts_Remaining_Pre AwayTimeouts_Remaining_Pre  \
# 0                     3                          3                          3
# 1                     3                          3                          3
# 2                     3                          3                          3
# 3                     3                          3                          3
# 4                     3                          3                          3
#
#    HomeTimeouts_Remaining_Post  AwayTimeouts_Remaining_Post  ExPoint_Prob  \
# 0                            3                            3           0.0
# 1                            3                            3           0.0
# 2                            3                            3           0.0
# 3                            3                            3           0.0
# 4                            3                            3           0.0
#
#    TwoPoint_Prob  Season
# 0            0.0    2009
# 1            0.0    2009
# 2            0.0    2009
# 3            0.0    2009
# 4            0.0    2009
#
# [5 rows x 41 columns]

# %%
# combien de données avons-nous perdues ?
print("Columns in original dataset: %d \n" % nfl_data.shape[1])
print("Columns with na's dropped: %d" % columns_with_na_dropped.shape[1])
# Out:
# Columns in original dataset: 102
#
# Columns with na's dropped: 41

# %% [markdown]
# Nous avons perdu pas mal de données, mais à ce stade, nous avons réussi à supprimer tous les NaN de nos données.

# %%
# Nous allons supprimer toutes les lignes de l'ensemble de données sf_permits qui contiennent des valeurs manquantes

sf_permits.dropna()

# Combien en reste-t-il ? = 0 ligne
# Out:
# Empty DataFrame
# Columns: [Permit Number, Permit Type, Permit Type Definition, Permit Creation Date, Block, Lot, Street Number, Street Number Suffix, Street Name, Street Suffix, Unit, Unit Suffix, Description, Current Status, Current Status Date, Filed Date, Issued Date, Completed Date, First Construction Document Date, Structural Notification, Number of Existing Stories, Number of Proposed Stories, Voluntary Soft-Story Retrofit, Fire Only Permit, Permit Expiration Date, Estimated Cost, Revised Cost, Existing Use, Existing Units, Proposed Use, Proposed Units, Plansets, TIDF Compliance, Existing Construction Type, Existing Construction Type Description, Proposed Construction Type, Proposed Construction Type Description, Site Permit, Supervisor District, Neighborhoods - Analysis Boundaries, Zipcode, Location, Record ID]
# Index: []
#
# [0 rows x 43 columns]

# %%
# supprimer toutes les colonnes contenant des valeurs vides (avec au moins une valeur manquante)

columns_with_na_dropped_sf_permits = sf_permits.dropna(axis=1)
columns_with_na_dropped_sf_permits.head()


# Quelle quantité de données reste-t-il ? 5 lignes
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Current Status  \
# 0           05/06/2015  0326  023            140       Ellis        expired
# 1           04/19/2016  0306  007            440       Geary         issued
# 2           05/27/2016  0595  203           1647     Pacific      withdrawn
# 3           11/07/2016  0156  011           1230     Pacific       complete
# 4           11/28/2016  0342  001            950      Market         issued
#
#   Current Status Date  Filed Date      Record ID
# 0          12/21/2017  05/06/2015  1380611233945
# 1          08/03/2017  04/19/2016  1420164406718
# 2          09/26/2017  05/27/2016  1424856504716
# 3          07/24/2017  11/07/2016  1443574295566
# 4          12/01/2017  11/28/2016   144548169992

# %%
# combien de données avons-nous perdues ?
print("Columns in original dataset: %d \n" % sf_permits.shape[1])
print("Columns with na's dropped: %d" % columns_with_na_dropped_sf_permits.shape[1])
# Out:
# Columns in original dataset: 43
#
# Columns with na's dropped: 12

# %% [markdown]
# # Remplir les valeurs manquantes automatiquement ( = imputation)
#
# Une autre option consiste à essayer de remplir les valeurs manquantes. Pour ce qui suit, j'obtiendrai une petite partie des données de la NFL afin que l'impression se passe bien.

# %%
# obtenir un petit sous-ensemble de l'ensemble de données NFL
subset_nfl_data = nfl_data.loc[:, 'EPA':'Season'].head()
subset_nfl_data
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474       NaN       NaN     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760       NaN       NaN     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796       NaN       NaN     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758       NaN       NaN    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295       NaN       NaN    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712       NaN       NaN    2009

# %% [markdown]
# Nous pouvons utiliser la fonction fillna() de Pandas pour remplir les valeurs manquantes d'une base de données. L'une des options dont nous disposons est de spécifier par quoi nous voulons que les valeurs NaN soient remplacées. Ici, je dis que j'aimerais remplacer toutes les valeurs NaN par 0.

# %%
# remplacer tous les NA par 0
subset_nfl_data.fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474  0.000000  0.000000     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  0.000000  0.000000     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758  0.000000  0.000000    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.000000  0.000000    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %% [markdown]
# Je pourrais également être un peu plus avisé et remplacer les valeurs manquantes par la valeur qui les suit directement dans la même colonne.
# Cela a beaucoup de sens pour les ensembles de données où les observations ont une sorte d'ordre logique.

# %%
# remplacer tous les NA par la valeur qui vient directement après dans la même colonne, 
# puis remplacer tous les NA qui suivent par 0
subset_nfl_data.fillna(method = 'bfill', axis=0).fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474 -1.068169  1.146076     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  3.318841 -5.031425     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758 -0.032244  0.036899    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.106663 -0.156239    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %%
# Rappel : Remplir les valeurs manquantes est également connu sous le nom d'"imputation"
